# %% [markdown]
# <a href="https://colab.research.google.com/github/pcarbo/colab/blob/main/my_first_colab_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
source("myfunctions.R")
scale.cols
# Out:
# Warning message in file(filename, "r", encoding = encoding):
# “cannot open file 'myfunctions.R': No such file or directory”
# Error in file(filename, "r", encoding = encoding): cannot open the connection
# Traceback:
#
# 1. source("myfunctions.R")
# 2. file(filename, "r", encoding = encoding)

# %% [markdown]
# # New Section

# %%
cat(system('python3 -c "from google.colab import drive\ndrive.mount()"', intern=TRUE), sep='\n', wait=TRUE)
# Out:
# Warning message in system("python3 -c \"from google.colab import drive\ndrive.mount()\"", :
# “running command 'python3 -c "from google.colab import drive
# drive.mount()"' had status 1”
# TRUE

# %%
?system

# %%
install.packages("rgl", repos = "http://cran.rstudio.com/")
install.packages("ConsRank", repos = "http://cran.rstudio.com/")
library("ConsRank")

# %%
getwd()
# Out:
# [1] "/content"

# %%
system("cat sample_data/README.md",intern = TRUE)
# Out:
#  [1] "This directory includes a few sample datasets to get you started."
#  [2] ""
#  [3] "*   `california_housing_data*.csv` is California housing data from the 1990 US"
#  [4] "    Census; more information is available at:"
#  [5] "    https://developers.google.com/machine-learning/crash-course/california-housing-data-description"
#  [6] ""
#  [7] "*   `mnist_*.csv` is a small sample of the"
#  [8] "    [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is"
#  [9] "    described at: http://yann.lecun.com/exdb/mnist/"
# [10] ""
# [11] "*   `anscombe.json` contains a copy of"
# [12] "    [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it"
# [13] "    was originally described in"
# [14] ""
# [15] "    Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American"
# [16] "    Statistician. 27 (1): 17-21. JSTOR 2682899."
# [17] ""
# [18] "    and our copy was prepared by the"
# [19] "    [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json)."

# %%
system("which R",intern = TRUE)
system("R --version",intern = TRUE)
# Out:
# [1] "/usr/local/bin/R"
#  [1] "R version 4.3.0 (2023-04-21) -- \"Already Tomorrow\""
#  [2] "Copyright (C) 2023 The R Foundation for Statistical Computing"
#  [3] "Platform: x86_64-pc-linux-gnu (64-bit)"
#  [4] ""
#  [5] "R is free software and comes with ABSOLUTELY NO WARRANTY."
#  [6] "You are welcome to redistribute it under the terms of the"
#  [7] "GNU General Public License versions 2 or 3."
#  [8] "For more information about these matters see"
#  [9] "https://www.gnu.org/licenses/."
# [10] ""

# %%
system("add-apt-repository -y ppa:marutter/rrutter")
system("add-apt-repository -y ppa:marutter/c2d4u")
system("apt-get update")
system("apt install -y r-cran-rstan")

# %%
install.packages('ggmap')
install.packages('codetools')

# %%
library("ggmap")
# Out:
# Error in library("ggmap"): there is no package called ‘ggmap’
# Traceback:
#
# 1. library("ggmap")

# %%
print('hello')
cat("Hi, how are you?\n")
# Out:
# [1] "hello"
# Hi, how are you?

# %%
hist(rnorm(1000),n = 64)
# Out:
# Plot with title “Histogram of rnorm(1000)”

# %%
system("ls /usr/local/lib/R/site-library/rgl/libs",intern = TRUE)
system("ldd /usr/local/lib/R/site-library/rgl/libs/rgl.so",intern = TRUE)
# Out:
# [1] "rgl.so"
#  [1] "\tlinux-vdso.so.1 (0x00007fff15cea000)"
#  [2] "\tlibGLU.so.1 => /usr/lib/x86_64-linux-gnu/libGLU.so.1 (0x00007f425de22000)"
#  [3] "\tlibGL.so.1 => /usr/lib/x86_64-linux-gnu/libGL.so.1 (0x00007f425dd9a000)"
#  [4] "\tlibpng16.so.16 => /usr/lib/x86_64-linux-gnu/libpng16.so.16 (0x00007f425dd62000)"
#  [5] "\tlibX11.so.6 => /usr/lib/x86_64-linux-gnu/libX11.so.6 (0x00007f425dc25000)"
#  [6] "\tlibfreetype.so.6 => /usr/lib/x86_64-linux-gnu/libfreetype.so.6 (0x00007f425db66000)"
#  [7] "\tlibm.so.6 => /usr/lib/x86_64-linux-gnu/libm.so.6 (0x00007f425da17000)"
#  [8] "\tlibR.so => /usr/lib/R/lib/libR.so (0x00007f425d59f000)"
#  [9] "\tlibstdc++.so.6 => /usr/lib/x86_64-linux-gnu/libstdc++.so.6 (0x00007f425d3bd000)"
# [10] "\tlibgcc_s.so.1 => /usr/lib/x86_64-linux-gnu/libgcc_s.so.1 (0x00007f425d3a2000)"
# [11] "\tlibc.so.6 => /usr/lib/x86_64-linux-gnu/libc.so.6 (0x00007f425d1b0000)"
# [12] "\tlibGLdispatch.so.0 => /usr/lib/x86_64-linux-gnu/libGLdispatch.so.0 (0x00007f425d0f8000)"
# [13] "\tlibGLX.so.0 => /usr/lib/x86_64-linux-gnu/libGLX.so.0 (0x00007f425d0c4000)"
# [14] "\tlibz.so.1 => /usr/lib/x86_64-linux-gnu/libz.so.1 (0x00007f425d0a6000)"
# [15] "\tlibxcb.so.1 => /usr/lib/x86_64-linux-gnu/libxcb.so.1 (0x00007f425d07c000)"
# [16] "\tlibdl.so.2 => /usr/lib/x86_64-linux-gnu/libdl.so.2 (0x00007f425d076000)"
# [17] "\t/lib64/ld-linux-x86-64.so.2 (0x00007f425df16000)"
# [18] "\tlibblas.so.3 => /usr/lib/x86_64-linux-gnu/libblas.so.3 (0x00007f425b677000)"
# [19] "\tlibreadline.so.8 => /usr/lib/x86_64-linux-gnu/libreadline.so.8 (0x00007f425b627000)"
# [20] "\tlibpcre2-8.so.0 => /usr/lib/x86_64-linux-gnu/libpcre2-8.so.0 (0x00007f425b596000)"
# [21] "\tliblzma.so.5 => /usr/lib/x86_64-linux-gnu/liblzma.so.5 (0x00007f425b56b000)"
# [22] "\tlibbz2.so.1.0 => /usr/lib/x86_64-linux-gnu/libbz2.so.1.0 (0x00007f425b558000)"
# [23] "\tlibicuuc.so.66 => /usr/lib/x86_64-linux-gnu/libicuuc.so.66 (0x00007f425b372000)"
# [24] "\tlibicui18n.so.66 => /usr/lib/x86_64-linux-gnu/libicui18n.so.66 (0x00007f425b073000)"
# [25] "\tlibgomp.so.1 => /usr/lib/x86_64-linux-gnu/libgomp.so.1 (0x00007f425b031000)"
# [26] "\tlibpthread.so.0 => /usr/lib/x86_64-linux-gnu/libpthread.so.0 (0x00007f425b00e000)"
# [27] "\tlibXau.so.6 => /usr/lib/x86_64-linux-gnu/libXau.so.6 (0x00007f425b006000)"
# [28] "\tlibXdmcp.so.6 => /usr/lib/x86_64-linux-gnu/libXdmcp.so.6 (0x00007f425affe000)"
# [29] "\tlibtinfo.so.6 => /usr/lib/x86_64-linux-gnu/libtinfo.so.6 (0x00007f425afce000)"
# [30] "\tlibicudata.so.66 => /usr/lib/x86_64-linux-gnu/libicudata.so.66 (0x00007f425950d000)"
# [31] "\tlibbsd.so.0 => /usr/lib/x86_64-linux-gnu/libbsd.so.0 (0x00007f42594f3000)"

# %%
options(repr.plot.width  = 3,
        repr.plot.height = 3)
Sys.setenv(USE_CXX14 = 1)
library("rstan") # observe startup messages
options(mc.cores = parallel::detectCores())
rstan_options(auto_write = TRUE)

# %% [markdown]
# This is the rank-1 GLM-PCA model: $x_{ij} \sim \mathrm{Pois}(\lambda_ij), \lambda_{ij} = e^{l_i f_j}$

# %%
system("apt list --installed",intern = TRUE)
# Out:
#    [1] "Listing..."
#    [2] "adduser/focal,now 3.118ubuntu2 all [installed]"
#    [3] "adwaita-icon-theme/focal-updates,now 3.36.1-2ubuntu0.20.04.2 all [installed,automatic]"
#    [4] "apt-utils/focal-updates,now 2.0.9 amd64 [installed]"
#    [5] "apt/focal-updates,now 2.0.9 amd64 [installed]"
#    [6] "autoconf/focal,now 2.69-11.1 all [installed,automatic]"
#    [7] "automake/focal,now 1:1.16.1-4ubuntu6 all [installed,automatic]"
#    [8] "autotools-dev/focal,now 20180224.1 all [installed,automatic]"
#    [9] "base-files/now 11ubuntu5.6 amd64 [installed,upgradable to: 11ubuntu5.7]"
#   [10] "base-passwd/focal,now 3.5.47 amd64 [installed]"
#   [11] "bash/focal-updates,focal-security,now 5.0-6ubuntu1.2 amd64 [installed]"
#   [12] "binutils-common/now 2.34-6ubuntu1.4 amd64 [installed,upgradable to: 2.34-6ubuntu1.5]"
#   [13] "binutils-x86-64-linux-gnu/now 2.34-6ubuntu1.4 amd64 [installed,upgradable to: 2.34-6ubuntu1.5]"
#   [14] "binutils/now 2.34-6ubuntu1.4 amd64 [installed,upgradable to: 2.34-6ubuntu1.5]"
#   [15] "bsdmainutils/focal,now 11.1.2ubuntu3 amd64 [installed,automatic]"
#   [16] "bsdutils/focal-updates,focal-security,now 1:2.34-0.1ubuntu9.3 amd64 [installed]"
#   [17] "build-essential/focal-updates,now 12.8ubuntu1.1 amd64 [installed]"
#   [18] "bzip2/focal,now 1.0.8-2 amd64 [installed]"
#   [19] "ca-certificates-java/focal-updates,focal-security,now 20190405ubuntu1.1 all [installed,automatic]"
#   [20] "ca-certificates/focal-updates,focal-security,now 20230311ubuntu0.20.04.1 all [installed]"
#   [21] "clang-10/focal,now 1:10.0.0-4ubuntu1 amd64 [installed,automatic]"
#   [22] "clang/focal,now 1:10.0-50~exp1 amd64 [installed]"
#   [23] "clinfo/focal,now 2.2.18.04.06-1 amd64 [installed]"
#   [24] "cmake-data/focal-updates,now 3.16.3-1ubuntu1.20.04.1 all [installed,automatic]"
#   [25] "cmake/focal-updates,now 3.16.3-1ubuntu1.20.04.1 amd64 [installed]"
#   [26] "comerr-dev/focal-updates,focal-security,now 2.1-1.45.5-2ubuntu1.1 amd64 [installed,automatic]"
#   [27] "coreutils/focal,now 8.30-3ubuntu2 amd64 [installed]"
#   [28] "cpp-9/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]"
#   [29] "cpp/focal,now 4:9.3.0-1ubuntu2 amd64 [installed,automatic]"
#   [30] "cuda-cccl-11-8/unknown,now 11.8.89-1 amd64 [installed,automatic]"
#   [31] "cuda-command-line-tools-11-8/unknown,now 11.8.0-1 amd64 [installed]"
#   [32] "cuda-compat-11-8/unknown,now 520.61.05-1 amd64 [installed]"
#   [33] "cuda-compiler-11-8/unknown,now 11.8.0-1 amd64 [installed,automatic]"
#   [34] "cuda-cudart-11-8/unknown,now 11.8.89-1 amd64 [installed]"
#   [35] "cuda-cudart-dev-11-8/unknown,now 11.8.89-1 amd64 [installed]"
#   [36] "cuda-cuobjdump-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]"
#   [37] "cuda-cupti-11-8/unknown,now 11.8.87-1 amd64 [installed,automatic]"
#   [38] "cuda-cupti-dev-11-8/unknown,now 11.8.87-1 amd64 [installed,automatic]"
#   [39] "cuda-cuxxfilt-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]"
#   [40] "cuda-driver-dev-11-8/unknown,now 11.8.89-1 amd64 [installed,automatic]"
#   [41] "cuda-gdb-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]"
#   [42] "cuda-libraries-11-8/unknown,now 11.8.0-1 amd64 [installed]"
#   [43] "cuda-libraries-dev-11-8/unknown,now 11.8.0-1 amd64 [installed]"
#   [44] "cuda-memcheck-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]"
#   [45] "cuda-minimal-build-11-8/unknown,now 11.8.0-1 amd64 [installed]"
#   [46] "cuda-nvcc-11-8/unknown,now 11.8.89-1 amd64 [installed,automatic]"
#   [47] "cuda-nvdisasm-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]"
#   [48] "cuda-nvml-dev-11-8/unknown,now 11.8.86-1 amd64 [installed]"
#   [49] "cuda-nvprof-11-8/unknown,now 11.8.87-1 amd64 [installed]"
#   [50] "cuda-nvprune-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]"
#   [51] "cuda-nvrtc-11-8/unknown,now 11.8.89-1 amd64 [installed,automatic]"
#   [52] "cuda-nvrtc-dev-11-8/unknown,now 11.8.89-1 amd64 [installed,automatic]"
#   [53] "cuda-nvtx-11-8/unknown,now 11.8.86-1 amd64 [installed]"
#   [54] "cuda-profiler-api-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]"
#   [55] "cuda-sanitizer-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]"
#   [56] "cuda-toolkit-11-8-config-common/unknown,now 11.8.89-1 all [installed,automatic]"
#   [57] "cuda-toolkit-11-config-common/unknown,now 11.8.89-1 all [installed,automatic]"
#   [58] "cuda-toolkit-config-common/unknown,now 12.0.146-1 all [installed,upgradable to: 12.1.105-1]"
#   [59] "curl/focal-updates,focal-security,now 7.68.0-1ubuntu2.18 amd64 [installed]"
#   [60] "dash/focal,now 0.5.10.2-6 amd64 [installed]"
#   [61] "dbus-user-session/focal-updates,focal-security,now 1.12.16-2ubuntu2.3 amd64 [installed,automatic]"
#   [62] "dbus/focal-updates,focal-security,now 1.12.16-2ubuntu2.3 amd64 [installed,automatic]"
#   [63] "dconf-gsettings-backend/focal,now 0.36.0-1 amd64 [installed,automatic]"
#   [64] "dconf-service/focal,now 0.36.0-1 amd64 [installed,automatic]"
#   [65] "debconf/focal,now 1.5.73 all [installed]"
#   [66] "debianutils/focal,now 4.9.1 amd64 [installed]"
#   [67] "default-libmysqlclient-dev/focal,now 1.0.5ubuntu2 amd64 [installed,automatic]"
#   [68] "diffutils/focal,now 1:3.7-3 amd64 [installed]"
#   [69] "dirmngr/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed]"
#   [70] "distro-info-data/focal-updates,now 0.43ubuntu1.13 all [installed,automatic]"
#   [71] "dpkg-dev/focal-updates,focal-security,now 1.19.7ubuntu3.2 all [installed,automatic]"
#   [72] "dpkg/focal-updates,focal-security,now 1.19.7ubuntu3.2 amd64 [installed]"
#   [73] "e2fsprogs/focal-updates,focal-security,now 1.45.5-2ubuntu1.1 amd64 [installed]"
#   [74] "fdisk/focal-updates,focal-security,now 2.34-0.1ubuntu9.3 amd64 [installed]"
#   [75] "ffmpeg/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed]"
#   [76] "file/focal,now 1:5.38-4 amd64 [installed]"
#   [77] "findutils/focal,now 4.7.0-1ubuntu1 amd64 [installed]"
#   [78] "fio/focal,now 3.16-1 amd64 [installed]"
#   [79] "fontconfig-config/focal,now 2.13.1-2ubuntu3 all [installed,automatic]"
#   [80] "fontconfig/focal,now 2.13.1-2ubuntu3 amd64 [installed,automatic]"
#   [81] "fonts-humor-sans/focal,now 1.0-3 all [installed]"
#   [82] "fonts-liberation/focal,now 1:1.07.4-11 all [installed]"
#   [83] "fuse/focal,now 2.9.9-3 amd64 [installed]"
#   [84] "g++-9/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]"
#   [85] "g++/focal,now 4:9.3.0-1ubuntu2 amd64 [installed,automatic]"
#   [86] "gcc-10-base/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed]"
#   [87] "gcc-9-base/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]"
#   [88] "gcc-9/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]"
#   [89] "gcc/focal,now 4:9.3.0-1ubuntu2 amd64 [installed,automatic]"
#   [90] "gdal-data/focal,now 3.3.2+dfsg-2~focal2 all [installed,automatic]"
#   [91] "gfortran-9/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]"
#   [92] "gfortran/focal,now 4:9.3.0-1ubuntu2 amd64 [installed]"
#   [93] "gir1.2-glib-2.0/focal-updates,now 1.64.1-1~ubuntu20.04.1 amd64 [installed,automatic]"
#   [94] "gir1.2-packagekitglib-1.0/focal-updates,focal-security,now 1.1.13-2ubuntu1.1 amd64 [installed,automatic]"
#   [95] "git-lfs/focal,now 2.9.2-1 amd64 [installed]"
#   [96] "git-man/focal-updates,focal-security,now 1:2.25.1-1ubuntu3.11 all [installed,automatic]"
#   [97] "git/focal-updates,focal-security,now 1:2.25.1-1ubuntu3.11 amd64 [installed]"
#   [98] "glib-networking-common/focal-updates,focal-security,now 2.64.2-1ubuntu0.1 all [installed,automatic]"
#   [99] "glib-networking-services/focal-updates,focal-security,now 2.64.2-1ubuntu0.1 amd64 [installed,automatic]"
#  [100] "glib-networking/focal-updates,focal-security,now 2.64.2-1ubuntu0.1 amd64 [installed,automatic]"
#  [101] "gnupg-l10n/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 all [installed,automatic]"
#  [102] "gnupg-utils/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]"
#  [103] "gnupg2/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 all [installed]"
#  [104] "gnupg/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 all [installed,automatic]"
#  [105] "google-perftools/focal,now 2.7-1ubuntu2 all [installed]"
#  [106] "gpg-agent/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]"
#  [107] "gpg-wks-client/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]"
#  [108] "gpg-wks-server/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]"
#  [109] "gpg/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]"
#  [110] "gpgconf/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]"
#  [111] "gpgsm/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]"
#  [112] "gpgv/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed]"
#  [113] "graphviz/focal,now 2.42.2-3build2 amd64 [installed]"
#  [114] "grep/focal,now 3.4-1 amd64 [installed]"
#  [115] "groff-base/focal,now 1.22.4-4build1 amd64 [installed,automatic]"
#  [116] "gsettings-desktop-schemas/focal,now 3.36.0-1ubuntu1 all [installed,automatic]"
#  [117] "gtk-update-icon-cache/focal-updates,now 3.24.20-0ubuntu1.1 amd64 [installed,automatic]"
#  [118] "gzip/focal-updates,focal-security,now 1.10-0ubuntu4.1 amd64 [installed]"
#  [119] "hdf5-helpers/focal,now 1.10.4+repack-11ubuntu1 amd64 [installed,automatic]"
#  [120] "hicolor-icon-theme/focal,now 0.17-2 all [installed,automatic]"
#  [121] "hostname/focal,now 3.23 amd64 [installed]"
#  [122] "humanity-icon-theme/focal,now 0.6.15 all [installed,automatic]"
#  [123] "ibverbs-providers/focal,now 28.0-1ubuntu1 amd64 [installed,automatic]"
#  [124] "icu-devtools/focal-updates,focal-security,now 66.1-2ubuntu2.1 amd64 [installed,automatic]"
#  [125] "init-system-helpers/focal,now 1.57 all [installed]"
#  [126] "iproute2/focal,now 5.5.0-1ubuntu1 amd64 [installed,automatic]"
#  [127] "iso-codes/focal,now 4.4-1 all [installed,automatic]"
#  [128] "java-common/focal,now 0.72 all [installed,automatic]"
#  [129] "kmod/focal-updates,now 27-1ubuntu2.1 amd64 [installed]"
#  [130] "krb5-multidev/focal-updates,focal-security,now 1.17-6ubuntu4.3 amd64 [installed,automatic]"
#  [131] "less/focal-updates,now 551-1ubuntu0.1 amd64 [installed]"
#  [132] "lib32gcc-s1/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed,automatic]"
#  [133] "lib32stdc++6/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed,automatic]"
#  [134] "libacl1/focal,now 2.2.53-6 amd64 [installed]"
#  [135] "libaec-dev/focal,now 1.0.4-1 amd64 [installed,automatic]"
#  [136] "libaec0/focal,now 1.0.4-1 amd64 [installed,automatic]"
#  [137] "libaio1/focal,now 0.3.112-5 amd64 [installed,automatic]"
#  [138] "libann0/focal,now 1.1.2+doc-7build1 amd64 [installed,automatic]"
#  [139] "libaom0/focal,now 1.0.0.errata1-3build1 amd64 [installed,automatic]"
#  [140] "libapparmor1/focal-updates,now 2.13.3-7ubuntu5.2 amd64 [installed,automatic]"
#  [141] "libappstream4/focal,now 0.12.10-2 amd64 [installed,automatic]"
#  [142] "libapt-pkg-dev/focal-updates,now 2.0.9 amd64 [installed]"
#  [143] "libapt-pkg6.0/focal-updates,now 2.0.9 amd64 [installed]"
#  [144] "libarchive13/focal-updates,focal-security,now 3.4.0-2ubuntu1.2 amd64 [installed,automatic]"
#  [145] "libargon2-1/focal,now 0~20171227-0.2 amd64 [installed,automatic]"
#  [146] "libarmadillo-dev/focal,now 1:9.800.4+dfsg-1build1 amd64 [installed,automatic]"
#  [147] "libarmadillo9/focal,now 1:9.800.4+dfsg-1build1 amd64 [installed,automatic]"
#  [148] "libarpack2-dev/focal,now 3.7.0-3 amd64 [installed,automatic]"
#  [149] "libarpack2/focal,now 3.7.0-3 amd64 [installed,automatic]"
#  [150] "libasan5/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]"
#  [151] "libasn1-8-heimdal/now 7.7.0+dfsg-1ubuntu1.3 amd64 [installed,upgradable to: 7.7.0+dfsg-1ubuntu1.4]"
#  [152] "libasound2-data/focal-updates,now 1.2.2-2.1ubuntu2.5 all [installed,automatic]"
#  [153] "libasound2-dev/focal-updates,now 1.2.2-2.1ubuntu2.5 amd64 [installed]"
#  [154] "libasound2/focal-updates,now 1.2.2-2.1ubuntu2.5 amd64 [installed,automatic]"
#  [155] "libass9/focal,now 1:0.14.0-2 amd64 [installed,automatic]"
#  [156] "libassuan0/focal,now 2.5.3-7ubuntu2 amd64 [installed,automatic]"
#  [157] "libasyncns0/focal,now 0.8-6 amd64 [installed,automatic]"
#  [158] "libatk-bridge2.0-0/focal-updates,now 2.34.2-0ubuntu2~20.04.1 amd64 [installed,automatic]"
#  [159] "libatk1.0-0/focal,now 2.35.1-1ubuntu2 amd64 [installed,automatic]"
#  [160] "libatk1.0-data/focal,now 2.35.1-1ubuntu2 all [installed,automatic]"
#  [161] "libatlas-base-dev/focal,now 3.10.3-8ubuntu7 amd64 [installed]"
#  [162] "libatlas3-base/focal,now 3.10.3-8ubuntu7 amd64 [installed,automatic]"
#  [163] "libatomic1/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed,automatic]"
#  [164] "libatspi2.0-0/focal,now 2.36.0-2 amd64 [installed,automatic]"
#  [165] "libattr1/focal,now 1:2.4.48-5 amd64 [installed]"
#  [166] "libaudit-common/focal,now 1:2.8.5-2ubuntu6 all [installed]"
#  [167] "libaudit1/focal,now 1:2.8.5-2ubuntu6 amd64 [installed]"
#  [168] "libavahi-client3/focal-updates,focal-security,now 0.7-4ubuntu7.1 amd64 [installed,automatic]"
#  [169] "libavahi-common-data/focal-updates,focal-security,now 0.7-4ubuntu7.1 amd64 [installed,automatic]"
#  [170] "libavahi-common3/focal-updates,focal-security,now 0.7-4ubuntu7.1 amd64 [installed,automatic]"
#  [171] "libavc1394-0/focal,now 0.5.4-5 amd64 [installed,automatic]"
#  [172] "libavcodec-dev/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]"
#  [173] "libavcodec58/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]"
#  [174] "libavdevice58/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed]"
#  [175] "libavfilter7/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]"
#  [176] "libavformat-dev/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]"
#  [177] "libavformat58/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]"
#  [178] "libavresample-dev/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]"
#  [179] "libavresample4/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]"
#  [180] "libavutil-dev/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]"
#  [181] "libavutil56/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]"
#  [182] "libbinutils/now 2.34-6ubuntu1.4 amd64 [installed,upgradable to: 2.34-6ubuntu1.5]"
#  [183] "libblkid1/focal-updates,focal-security,now 2.34-0.1ubuntu9.3 amd64 [installed]"
#  [184] "libblocksruntime-dev/focal,now 0.4.1-1.1 amd64 [installed]"
#  [185] "libblocksruntime0/focal,now 0.4.1-1.1 amd64 [installed,automatic]"
#  [186] "libbluray2/focal,now 1:1.2.0-1 amd64 [installed,automatic]"
#  [187] "libboost-all-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed]"
#  [188] "libboost-atomic-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [189] "libboost-atomic1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [190] "libboost-atomic1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [191] "libboost-chrono-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [192] "libboost-chrono1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [193] "libboost-chrono1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [194] "libboost-container-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [195] "libboost-container1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [196] "libboost-container1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [197] "libboost-context-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [198] "libboost-context1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [199] "libboost-context1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [200] "libboost-coroutine-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [201] "libboost-coroutine1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [202] "libboost-coroutine1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [203] "libboost-date-time-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [204] "libboost-date-time1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [205] "libboost-date-time1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [206] "libboost-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [207] "libboost-exception-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [208] "libboost-exception1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [209] "libboost-fiber-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [210] "libboost-fiber1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [211] "libboost-fiber1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [212] "libboost-filesystem-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [213] "libboost-filesystem1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [214] "libboost-filesystem1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [215] "libboost-graph-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [216] "libboost-graph-parallel-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [217] "libboost-graph-parallel1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [218] "libboost-graph-parallel1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [219] "libboost-graph1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [220] "libboost-graph1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [221] "libboost-iostreams-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [222] "libboost-iostreams1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [223] "libboost-iostreams1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [224] "libboost-locale-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [225] "libboost-locale1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [226] "libboost-locale1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [227] "libboost-log-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [228] "libboost-log1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [229] "libboost-log1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [230] "libboost-math-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [231] "libboost-math1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [232] "libboost-math1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [233] "libboost-mpi-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [234] "libboost-mpi-python-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [235] "libboost-mpi-python1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [236] "libboost-mpi-python1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [237] "libboost-mpi1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [238] "libboost-mpi1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [239] "libboost-numpy-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [240] "libboost-numpy1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [241] "libboost-numpy1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [242] "libboost-program-options-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [243] "libboost-program-options1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [244] "libboost-program-options1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [245] "libboost-python-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [246] "libboost-python1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [247] "libboost-python1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [248] "libboost-random-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [249] "libboost-random1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [250] "libboost-random1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [251] "libboost-regex-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [252] "libboost-regex1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [253] "libboost-regex1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [254] "libboost-serialization-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [255] "libboost-serialization1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [256] "libboost-serialization1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [257] "libboost-stacktrace-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [258] "libboost-stacktrace1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [259] "libboost-stacktrace1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [260] "libboost-system-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [261] "libboost-system1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [262] "libboost-system1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [263] "libboost-test-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [264] "libboost-test1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [265] "libboost-test1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [266] "libboost-thread-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [267] "libboost-thread1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [268] "libboost-thread1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [269] "libboost-timer-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [270] "libboost-timer1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [271] "libboost-timer1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [272] "libboost-tools-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [273] "libboost-type-erasure-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [274] "libboost-type-erasure1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [275] "libboost-type-erasure1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [276] "libboost-wave-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]"
#  [277] "libboost-wave1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [278] "libboost-wave1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [279] "libboost1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [280] "libboost1.71-tools-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]"
#  [281] "libbrotli1/focal-updates,focal-security,now 1.0.7-6ubuntu0.1 amd64 [installed,automatic]"
#  [282] "libbs2b0/focal,now 3.1.0+dfsg-2.2build1 amd64 [installed,automatic]"
#  [283] "libbsd0/focal,now 0.10.0-1 amd64 [installed,automatic]"
#  [284] "libbz2-1.0/focal,now 1.0.8-2 amd64 [installed]"
#  [285] "libbz2-dev/focal,now 1.0.8-2 amd64 [installed,automatic]"
#  [286] "libc-bin/focal-updates,now 2.31-0ubuntu9.9 amd64 [installed]"
#  [287] "libc-dev-bin/focal-updates,now 2.31-0ubuntu9.9 amd64 [installed,automatic]"
#  [288] "libc6-dev/focal-updates,now 2.31-0ubuntu9.9 amd64 [installed,automatic]"
#  [289] "libc6-i386/focal-updates,now 2.31-0ubuntu9.9 amd64 [installed,automatic]"
#  [290] "libc6/focal-updates,now 2.31-0ubuntu9.9 amd64 [installed]"
#  [291] "libcaca0/focal-updates,focal-security,now 0.99.beta19-2.1ubuntu1.20.04.2 amd64 [installed,automatic]"
#  [292] "libcairo-gobject2/focal,now 1.16.0-4ubuntu1 amd64 [installed,automatic]"
#  [293] "libcairo2/focal,now 1.16.0-4ubuntu1 amd64 [installed,automatic]"
#  [294] "libcanberra0/focal,now 0.30-7ubuntu1 amd64 [installed,automatic]"
#  [295] "libcap-ng0/focal,now 0.7.9-2.1build1 amd64 [installed]"
#  [296] "libcap2-bin/focal,now 1:2.32-1 amd64 [installed,automatic]"
#  [297] "libcap2/focal,now 1:2.32-1 amd64 [installed,automatic]"
#  [298] "libcbor0.6/focal,now 0.6.0-0ubuntu1 amd64 [installed,automatic]"
#  [299] "libcc1-0/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed,automatic]"
#  [300] "libcdio-cdda2/focal,now 10.2+2.0.0-1 amd64 [installed,automatic]"
#  [301] "libcdio-paranoia2/focal,now 10.2+2.0.0-1 amd64 [installed,automatic]"
#  [302] "libcdio18/focal,now 2.0.0-2 amd64 [installed,automatic]"
#  [303] "libcdt5/focal,now 2.42.2-3build2 amd64 [installed,automatic]"
#  [304] "libcfitsio-dev/focal,now 3.470-3 amd64 [installed,automatic]"
#  [305] "libcfitsio8/focal,now 3.470-3 amd64 [installed,automatic]"
#  [306] "libcgraph6/focal,now 2.42.2-3build2 amd64 [installed,automatic]"
#  [307] "libcharls-dev/focal,now 2.0.0+dfsg-1build1 amd64 [installed,automatic]"
#  [308] "libcharls2/focal,now 2.0.0+dfsg-1build1 amd64 [installed,automatic]"
#  [309] "libchromaprint1/focal,now 1.4.3-3build1 amd64 [installed,automatic]"
#  [310] "libclang-common-10-dev/focal,now 1:10.0.0-4ubuntu1 amd64 [installed,automatic]"
#  [311] "libclang-cpp10/focal,now 1:10.0.0-4ubuntu1 amd64 [installed,automatic]"
#  [312] "libclang1-10/focal,now 1:10.0.0-4ubuntu1 amd64 [installed,automatic]"
#  [313] "libcodec2-0.9/focal,now 0.9.2-2 amd64 [installed,automatic]"
#  [314] "libcolord2/focal,now 1.4.4-2 amd64 [installed,automatic]"
#  [315] "libcom-err2/focal-updates,focal-security,now 1.45.5-2ubuntu1.1 amd64 [installed]"
#  [316] "libcrypt-dev/focal,now 1:4.4.10-10ubuntu4 amd64 [installed,automatic]"
#  [317] "libcrypt1/focal,now 1:4.4.10-10ubuntu4 amd64 [installed]"
#  [318] "libcryptsetup12/focal-updates,focal-security,now 2:2.2.2-3ubuntu2.4 amd64 [installed,automatic]"
#  [319] "libctf-nobfd0/now 2.34-6ubuntu1.4 amd64 [installed,upgradable to: 2.34-6ubuntu1.5]"
#  [320] "libctf0/now 2.34-6ubuntu1.4 amd64 [installed,upgradable to: 2.34-6ubuntu1.5]"
#  [321] "libcublas-11-8/unknown,now 11.11.3.6-1 amd64 [installed]"
#  [322] "libcublas-dev-11-8/unknown,now 11.11.3.6-1 amd64 [installed]"
#  [323] "libcudnn8-dev/unknown,now 8.7.0.84-1+cuda11.8 amd64 [installed,upgradable to: 8.9.1.23-1+cuda12.1]"
#  [324] "libcudnn8/unknown,now 8.7.0.84-1+cuda11.8 amd64 [installed,upgradable to: 8.9.1.23-1+cuda12.1]"
#  [325] "libcufft-11-8/unknown,now 10.9.0.58-1 amd64 [installed,automatic]"
#  [326] "libcufft-dev-11-8/unknown,now 10.9.0.58-1 amd64 [installed,automatic]"
#  [327] "libcufile-11-8/unknown,now 1.4.0.31-1 amd64 [installed,automatic]"
#  [328] "libcufile-dev-11-8/unknown,now 1.4.0.31-1 amd64 [installed,automatic]"
#  [329] "libcups2/focal-updates,focal-security,now 2.3.1-9ubuntu1.2 amd64 [installed,automatic]"
#  [330] "libcurand-11-8/unknown,now 10.3.0.86-1 amd64 [installed,automatic]"
#  [331] "libcurand-dev-11-8/unknown,now 10.3.0.86-1 amd64 [installed,automatic]"
#  [332] "libcurl3-gnutls/focal-updates,focal-security,now 7.68.0-1ubuntu2.18 amd64 [installed,automatic]"
#  [333] "libcurl4-openssl-dev/focal-updates,focal-security,now 7.68.0-1ubuntu2.18 amd64 [installed]"
#  [334] "libcurl4/focal-updates,focal-security,now 7.68.0-1ubuntu2.18 amd64 [installed]"
#  [335] "libcusolver-11-8/unknown,now 11.4.1.48-1 amd64 [installed,automatic]"
#  [336] "libcusolver-dev-11-8/unknown,now 11.4.1.48-1 amd64 [installed,automatic]"
#  [337] "libcusparse-11-8/unknown,now 11.7.5.86-1 amd64 [installed]"
#  [338] "libcusparse-dev-11-8/unknown,now 11.7.5.86-1 amd64 [installed]"
#  [339] "libdatrie1/focal,now 0.2.12-3 amd64 [installed,automatic]"
#  [340] "libdb5.3/focal,now 5.3.28+dfsg1-0.6ubuntu2 amd64 [installed]"
#  [341] "libdbus-1-3/focal-updates,focal-security,now 1.12.16-2ubuntu2.3 amd64 [installed,automatic]"
#  [342] "libdc1394-22-dev/focal,now 2.2.5-2.1 amd64 [installed,automatic]"
#  [343] "libdc1394-22/focal,now 2.2.5-2.1 amd64 [installed,automatic]"
#  [344] "libdconf1/focal,now 0.36.0-1 amd64 [installed,automatic]"
#  [345] "libde265-0/focal,now 1.0.4-1build1 amd64 [installed,automatic]"
#  [346] "libdebconfclient0/focal,now 0.251ubuntu1 amd64 [installed]"
#  [347] "libdeflate-dev/focal,now 1.5-3 amd64 [installed,automatic]"
#  [348] "libdeflate0/focal,now 1.5-3 amd64 [installed,automatic]"
#  [349] "libdevmapper1.02.1/focal,now 2:1.02.167-1ubuntu1 amd64 [installed,automatic]"
#  [350] "libdouble-conversion3/focal,now 3.1.5-4ubuntu1 amd64 [installed,automatic]"
#  [351] "libdpkg-perl/focal-updates,focal-security,now 1.19.7ubuntu3.2 all [installed,automatic]"
#  [352] "libdrm-amdgpu1/focal-updates,focal-security,now 2.4.107-8ubuntu1~20.04.2 amd64 [installed,automatic]"
#  [353] "libdrm-common/focal-updates,focal-security,now 2.4.107-8ubuntu1~20.04.2 all [installed,automatic]"
#  [354] "libdrm-intel1/focal-updates,focal-security,now 2.4.107-8ubuntu1~20.04.2 amd64 [installed,automatic]"
#  [355] "libdrm-nouveau2/focal-updates,focal-security,now 2.4.107-8ubuntu1~20.04.2 amd64 [installed,automatic]"
#  [356] "libdrm-radeon1/focal-updates,focal-security,now 2.4.107-8ubuntu1~20.04.2 amd64 [installed,automatic]"
#  [357] "libdrm2/focal-updates,focal-security,now 2.4.107-8ubuntu1~20.04.2 amd64 [installed,automatic]"
#  [358] "libedit2/focal,now 3.1-20191231-1 amd64 [installed,automatic]"
#  [359] "libegl-dev/focal-updates,focal-security,now 1.3.2-1~ubuntu0.20.04.2 amd64 [installed,automatic]"
#  [360] "libegl-mesa0/focal-updates,focal-security,now 21.2.6-0ubuntu0.1~20.04.2 amd64 [installed,automatic]"
#  [361] "libegl1/focal-updates,focal-security,now 1.3.2-1~ubuntu0.20.04.2 amd64 [installed]"
#  [362] "libelf1/focal,now 0.176-1.1build1 amd64 [installed,automatic]"
#  [363] "libepoxy0/focal,now 1.5.4-1 amd64 [installed,automatic]"
#  [364] "liberror-perl/focal,now 0.17029-1 all [installed,automatic]"
#  [365] "libevdev2/focal-updates,focal-security,now 1.9.0+dfsg-1ubuntu0.2 amd64 [installed,automatic]"
#  [366] "libevent-2.1-7/focal,now 2.1.11-stable-1 amd64 [installed,automatic]"
#  [367] "libevent-core-2.1-7/focal,now 2.1.11-stable-1 amd64 [installed,automatic]"
#  [368] "libevent-dev/focal,now 2.1.11-stable-1 amd64 [installed,automatic]"
#  [369] "libevent-extra-2.1-7/focal,now 2.1.11-stable-1 amd64 [installed,automatic]"
#  [370] "libevent-openssl-2.1-7/focal,now 2.1.11-stable-1 amd64 [installed,automatic]"
#  [371] "libevent-pthreads-2.1-7/focal,now 2.1.11-stable-1 amd64 [installed,automatic]"
#  [372] "libexif-dev/focal-updates,focal-security,now 0.6.21-6ubuntu0.4 amd64 [installed,automatic]"
#  [373] "libexif12/focal-updates,focal-security,now 0.6.21-6ubuntu0.4 amd64 [installed,automatic]"
#  [374] "libexpat1-dev/focal-updates,focal-security,now 2.2.9-1ubuntu0.6 amd64 [installed,automatic]"
#  [375] "libexpat1/focal-updates,focal-security,now 2.2.9-1ubuntu0.6 amd64 [installed,automatic]"
#  [376] "libext2fs2/focal-updates,focal-security,now 1.45.5-2ubuntu1.1 amd64 [installed]"
#  [377] "libfabric1/focal-updates,now 1.6.2-3ubuntu0.1 amd64 [installed,automatic]"
#  [378] "libfdisk1/focal-updates,focal-security,now 2.34-0.1ubuntu9.3 amd64 [installed]"
#  [379] "libffi7/focal,now 3.3-4 amd64 [installed]"
#  [380] "libfftw3-double3/focal,now 3.3.8-2ubuntu1 amd64 [installed,automatic]"
#  [381] "libfido2-1/focal,now 1.3.1-1ubuntu2 amd64 [installed,automatic]"
#  [382] "libflac-dev/focal-updates,focal-security,now 1.3.3-1ubuntu0.1 amd64 [installed,automatic]"
#  [383] "libflac8/focal-updates,focal-security,now 1.3.3-1ubuntu0.1 amd64 [installed,automatic]"
#  [384] "libflite1/focal,now 2.1-release-3 amd64 [installed,automatic]"
# ...
# [1107] "r-cran-lifecycle/focal,now 1.0.3-1cran1.2004.0 all [installed,automatic]"
# [1108] "r-cran-lubridate/focal,now 1.9.2-1cran1.2004.0 amd64 [installed,automatic]"
# [1109] "r-cran-magrittr/focal,now 2.0.3-1cran1.2004.0 amd64 [installed,automatic]"
# [1110] "r-cran-mass/focal,now 7.3-60-1cran1.2004.0 amd64 [installed,automatic]"
# [1111] "r-cran-matrix/focal,now 1.5-4.1-1cran1.2004.0 amd64 [installed,automatic]"
# [1112] "r-cran-memoise/focal,now 2.0.1-1cran1.2004.0 all [installed,automatic]"
# [1113] "r-cran-mgcv/focal-cran40,now 1.8-42-1cran1.2004.0 amd64 [installed,automatic]"
# [1114] "r-cran-mime/focal,now 0.12-1cran1.2004.0 amd64 [installed,automatic]"
# [1115] "r-cran-modelr/focal,now 0.1.11-1cran1.2004.0 all [installed,automatic]"
# [1116] "r-cran-munsell/focal,now 0.5.0-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]"
# [1117] "r-cran-nlme/focal-cran40,now 3.1.162-1.2004.0 amd64 [installed,automatic]"
# [1118] "r-cran-nnet/focal,now 7.3-19-1cran1.2004.0 amd64 [installed,automatic]"
# [1119] "r-cran-openssl/focal,now 2.0.6-1cran1.2004.0 amd64 [installed,automatic]"
# [1120] "r-cran-pillar/focal,now 1.9.0-1cran1.2004.0 all [installed,automatic]"
# [1121] "r-cran-pkgbuild/focal,now 1.4.0-1cran1.2004.0 all [installed,automatic]"
# [1122] "r-cran-pkgconfig/focal,now 2.0.3-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]"
# [1123] "r-cran-pkgload/focal,now 1.3.1-1cran1.2004.0 all [installed,automatic]"
# [1124] "r-cran-praise/focal,now 1.0.0-3.1~ubuntu20.04.1~ppa1 all [installed,automatic]"
# [1125] "r-cran-prettyunits/focal,now 1.1.1-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]"
# [1126] "r-cran-processx/focal,now 3.8.1-1cran1.2004.0 amd64 [installed,automatic]"
# [1127] "r-cran-progress/focal,now 1.2.2-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]"
# [1128] "r-cran-ps/focal,now 1.7.5-1cran1.2004.0 amd64 [installed,automatic]"
# [1129] "r-cran-purrr/focal,now 1.0.1-1cran1.2004.0 amd64 [installed,automatic]"
# [1130] "r-cran-r6/focal,now 2.5.1-1cran1.2004.0 all [installed,automatic]"
# [1131] "r-cran-rappdirs/focal,now 0.3.3-1cran1.2004.0 amd64 [installed,automatic]"
# [1132] "r-cran-rcmdcheck/focal,now 1.4.0-1cran1.2004.0 all [installed,automatic]"
# [1133] "r-cran-rcolorbrewer/focal,now 1.1-3-1cran1.2004.0 all [installed,automatic]"
# [1134] "r-cran-readr/focal,now 2.1.4-1cran1.2004.0 amd64 [installed,automatic]"
# [1135] "r-cran-readxl/focal,now 1.4.2-1cran1.2004.0 amd64 [installed,automatic]"
# [1136] "r-cran-rematch2/focal,now 2.1.2-1cran1.2004.0 all [installed,automatic]"
# [1137] "r-cran-rematch/focal,now 1.0.1-2.1~ubuntu20.04.1~ppa1 all [installed,automatic]"
# [1138] "r-cran-remotes/focal,now 2.4.2-1cran1.2004.0 all [installed,automatic]"
# [1139] "r-cran-reprex/focal,now 2.0.2-1cran1.2004.0 all [installed,automatic]"
# [1140] "r-cran-rlang/focal,now 1.1.1-1cran1.2004.0 amd64 [installed,automatic]"
# [1141] "r-cran-rmarkdown/focal,now 2.21-1cran1.2004.0 all [installed,automatic]"
# [1142] "r-cran-roxygen2/focal,now 7.2.2-1cran1.2004.0 amd64 [installed,automatic]"
# [1143] "r-cran-rpart/focal-cran40,now 4.1.19-1.2004.0 amd64 [installed,automatic]"
# [1144] "r-cran-rprojroot/focal,now 2.0.3-1cran1.2004.0 all [installed,automatic]"
# [1145] "r-cran-rstudioapi/focal,now 0.14-1cran1.2004.0 all [installed,automatic]"
# [1146] "r-cran-rversions/focal,now 2.1.2-1cran1.2004.0 all [installed,automatic]"
# [1147] "r-cran-rvest/focal,now 1.0.3-1cran1.2004.0 all [installed,automatic]"
# [1148] "r-cran-sass/focal,now 0.4.6-1cran1.2004.0 amd64 [installed,automatic]"
# [1149] "r-cran-scales/focal,now 1.2.1-1cran1.2004.0 all [installed,automatic]"
# [1150] "r-cran-selectr/focal,now 0.4-2-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]"
# [1151] "r-cran-sessioninfo/focal,now 1.2.2-1cran1.2004.0 all [installed,automatic]"
# [1152] "r-cran-spatial/focal,now 7.3-16-1cran1.2004.0 amd64 [installed,automatic]"
# [1153] "r-cran-stringi/focal,now 1.7.12-1cran1.2004.0 amd64 [installed,automatic]"
# [1154] "r-cran-stringr/focal,now 1.5.0-1cran1.2004.0 all [installed,automatic]"
# [1155] "r-cran-survival/focal-cran40,now 3.5-5-1cran1.2004.0 amd64 [installed,automatic]"
# [1156] "r-cran-svglite/focal,now 2.1.1-1cran1.2004.0 amd64 [installed,automatic]"
# [1157] "r-cran-sys/focal,now 3.4.1-1cran1.2004.0 amd64 [installed,automatic]"
# [1158] "r-cran-systemfonts/focal,now 1.0.4-1cran1.2004.0 amd64 [installed,automatic]"
# [1159] "r-cran-testthat/focal,now 3.1.8-1cran1.2004.0 amd64 [installed,automatic]"
# [1160] "r-cran-tibble/focal,now 3.2.1-1cran1.2004.0 amd64 [installed,automatic]"
# [1161] "r-cran-tidyr/focal,now 1.3.0-1cran1.2004.0 amd64 [installed,automatic]"
# [1162] "r-cran-tidyselect/focal,now 1.2.0-1cran1.2004.0 all [installed,automatic]"
# [1163] "r-cran-tidyverse/focal,now 1.3.1-1cran1.2004.0 all [installed]"
# [1164] "r-cran-timechange/focal,now 0.2.0-1cran1.2004.0 amd64 [installed,automatic]"
# [1165] "r-cran-tinytex/focal,now 0.45-1cran1.2004.0 all [installed,automatic]"
# [1166] "r-cran-tzdb/focal,now 0.4.0-1cran1.2004.0 amd64 [installed,automatic]"
# [1167] "r-cran-usethis/focal,now 2.1.6-1cran1.2004.0 all [installed,automatic]"
# [1168] "r-cran-utf8/focal,now 1.2.3-1cran1.2004.0 amd64 [installed,automatic]"
# [1169] "r-cran-uuid/focal,now 1.1-0-1cran1.2004.0 amd64 [installed,automatic]"
# [1170] "r-cran-vctrs/focal,now 0.6.2-1cran1.2004.0 amd64 [installed,automatic]"
# [1171] "r-cran-viridislite/focal,now 0.4.2-1cran1.2004.0 all [installed,automatic]"
# [1172] "r-cran-vroom/focal,now 1.6.3-1cran1.2004.0 amd64 [installed,automatic]"
# [1173] "r-cran-waldo/focal,now 0.5.1-1cran1.2004.0 all [installed,automatic]"
# [1174] "r-cran-whisker/focal,now 0.4-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]"
# [1175] "r-cran-withr/focal,now 2.5.0-1cran1.2004.0 all [installed,automatic]"
# [1176] "r-cran-xfun/focal,now 0.39-1cran1.2004.0 amd64 [installed,automatic]"
# [1177] "r-cran-xml2/focal,now 1.3.4-1cran1.2004.0 amd64 [installed,automatic]"
# [1178] "r-cran-xopen/focal,now 1.0.0-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]"
# [1179] "r-cran-yaml/focal,now 2.3.7-1cran1.2004.0 amd64 [installed,automatic]"
# [1180] "r-cran-zip/focal,now 2.3.0-1cran1.2004.0 amd64 [installed,automatic]"
# [1181] "r-recommended/focal-cran40,now 4.3.0-1.2004.0 all [installed,automatic]"
# [1182] "readline-common/focal,now 8.0-4 all [installed,automatic]"
# [1183] "rename/focal,now 1.10-1 all [installed]"
# [1184] "rsync/focal-updates,focal-security,now 3.1.3-8ubuntu0.5 amd64 [installed]"
# [1185] "sed/focal,now 4.7-1 amd64 [installed]"
# [1186] "sensible-utils/focal,now 0.0.12+nmu1 all [installed]"
# [1187] "shared-mime-info/focal,now 1.15-1 amd64 [installed,automatic]"
# [1188] "software-properties-common/focal-updates,now 0.99.9.11 all [installed]"
# [1189] "sound-theme-freedesktop/focal,now 0.8-2ubuntu1 all [installed,automatic]"
# [1190] "sudo/focal-updates,focal-security,now 1.8.31-1ubuntu1.5 amd64 [installed]"
# [1191] "systemd-sysv/focal-updates,now 245.4-4ubuntu3.21 amd64 [installed,automatic]"
# [1192] "systemd-timesyncd/focal-updates,now 245.4-4ubuntu3.21 amd64 [installed,automatic]"
# [1193] "systemd/focal-updates,now 245.4-4ubuntu3.21 amd64 [installed,automatic]"
# [1194] "sysvinit-utils/focal,now 2.96-2.1ubuntu1 amd64 [installed]"
# [1195] "tar/now 1.30+dfsg-7ubuntu0.20.04.2 amd64 [installed,upgradable to: 1.30+dfsg-7ubuntu0.20.04.3]"
# [1196] "tcl-dev/focal,now 8.6.9+1 amd64 [installed]"
# [1197] "tcl8.6-dev/focal,now 8.6.10+dfsg-1 amd64 [installed,automatic]"
# [1198] "tcl8.6/focal,now 8.6.10+dfsg-1 amd64 [installed,automatic]"
# [1199] "tcl/focal,now 8.6.9+1 amd64 [installed,automatic]"
# [1200] "tcllib/focal,now 1.20+dfsg-1 all [installed]"
# [1201] "tk-dev/focal,now 8.6.9+1 amd64 [installed]"
# [1202] "tk8.6-dev/focal,now 8.6.10-1 amd64 [installed,automatic]"
# [1203] "tk8.6/focal,now 8.6.10-1 amd64 [installed,automatic]"
# [1204] "tk/focal,now 8.6.9+1 amd64 [installed,automatic]"
# [1205] "tmux/focal-updates,focal-security,now 3.0a-2ubuntu0.4 amd64 [installed]"
# [1206] "tzdata/focal-updates,now 2023c-0ubuntu0.20.04.1 all [installed,automatic]"
# [1207] "ubuntu-keyring/focal-updates,now 2020.02.11.4 all [installed]"
# [1208] "ubuntu-mono/focal,now 19.04-0ubuntu3 all [installed,automatic]"
# [1209] "ucf/focal,now 3.0038+nmu1 all [installed,automatic]"
# [1210] "unixodbc-dev/focal,now 2.3.6-0.1build1 amd64 [installed,automatic]"
# [1211] "unrar/focal,now 1:5.6.6-2build1 amd64 [installed]"
# [1212] "unzip/focal-updates,focal-security,now 6.0-25ubuntu1.1 amd64 [installed]"
# [1213] "util-linux/focal-updates,focal-security,now 2.34-0.1ubuntu9.3 amd64 [installed]"
# [1214] "uuid-dev/focal-updates,focal-security,now 2.34-0.1ubuntu9.3 amd64 [installed,automatic]"
# [1215] "vim-common/focal-updates,focal-security,now 2:8.1.2269-1ubuntu5.14 all [installed,automatic]"
# [1216] "vim-runtime/focal-updates,focal-security,now 2:8.1.2269-1ubuntu5.14 all [installed,automatic]"
# [1217] "vim/focal-updates,focal-security,now 2:8.1.2269-1ubuntu5.14 amd64 [installed]"
# [1218] "wget/focal-updates,now 1.20.3-1ubuntu2 amd64 [installed]"
# [1219] "x11-common/focal,now 1:7.7+19ubuntu14 all [installed,automatic]"
# [1220] "x11proto-core-dev/focal,now 2019.2-1ubuntu1 all [installed,automatic]"
# [1221] "x11proto-dev/focal,now 2019.2-1ubuntu1 all [installed,automatic]"
# [1222] "x11proto-scrnsaver-dev/focal,now 2019.2-1ubuntu1 all [installed,automatic]"
# [1223] "x11proto-xext-dev/focal,now 2019.2-1ubuntu1 all [installed,automatic]"
# [1224] "xauth/focal,now 1:1.1-0ubuntu1 amd64 [installed,automatic]"
# [1225] "xdg-utils/focal-updates,focal-security,now 1.1.3-2ubuntu1.20.04.2 all [installed,automatic]"
# [1226] "xkb-data/focal,now 2.29-2 all [installed,automatic]"
# [1227] "xorg-sgml-doctools/focal,now 1:1.11-1 all [installed,automatic]"
# [1228] "xsel/focal,now 1.2.0+git9bfc13d.20180109-3 amd64 [installed,automatic]"
# [1229] "xtrans-dev/focal,now 1.4.0-1 all [installed,automatic]"
# [1230] "xxd/focal-updates,focal-security,now 2:8.1.2269-1ubuntu5.14 amd64 [installed,automatic]"
# [1231] "xz-utils/focal-updates,focal-security,now 5.2.4-1ubuntu1.1 amd64 [installed,automatic]"
# [1232] "zip/focal,now 3.0-11build1 amd64 [installed]"
# [1233] "zlib1g-dev/focal-updates,focal-security,now 1:1.2.11.dfsg-2ubuntu1.5 amd64 [installed,automatic]"
# [1234] "zlib1g/focal-updates,focal-security,now 1:1.2.11.dfsg-2ubuntu1.5 amd64 [installed]"

# %%
cat(system("cat /proc/cpuinfo",intern = TRUE),sep = "\n")
cat(system("cat /proc/meminfo",intern = TRUE),sep = "\n")
cat(system("cat /proc/version",intern = TRUE),sep = "\n")
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# MemTotal:       13294264 kB
# MemFree:         9769460 kB
# MemAvailable:   12281412 kB
# Buffers:          326608 kB
# Cached:          2386836 kB
# SwapCached:            0 kB
# Active:           754572 kB
# Inactive:        2525620 kB
# Active(anon):       3248 kB
# Inactive(anon):   578856 kB
# Active(file):     751324 kB
# Inactive(file):  1946764 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               168 kB
# Writeback:             0 kB
# AnonPages:        561032 kB
# Mapped:           311308 kB
# Shmem:             15356 kB
# KReclaimable:     109636 kB
# Slab:             145436 kB
# SReclaimable:     109636 kB
# SUnreclaim:        35800 kB
# KernelStack:        4000 kB
# PageTables:         8880 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6647132 kB
# Committed_AS:    2000480 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:        8972 kB
# VmallocChunk:          0 kB
# Percpu:             1296 kB
# HardwareCorrupted:     0 kB
# AnonHugePages:     14336 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:       92984 kB
# DirectMap2M:     5146624 kB
# DirectMap1G:    10485760 kB
# Linux version 5.15.107+ (builder@localhost) (Chromium OS 14.0_pre445002_p20220217-r3 clang version 14.0.0 (/var/tmp/portage/sys-devel/llvm-14.0_pre445002_p20220217-r3/work/llvm-14.0_pre445002_p20220217/clang 18308e171b5b1dd99627a4d88c7d6c5ff21b8c96), LLD 14.0.0) #1 SMP Sat Apr 29 09:15:28 UTC 2023

# %%
system("apt-get install libgsl-dev",intern = TRUE)
# Out:
#  [1] "Reading package lists..."
#  [2] "Building dependency tree..."
#  [3] "Reading state information..."
#  [4] "The following additional packages will be installed:"
#  [5] "  libgsl23 libgslcblas0"
#  [6] "Suggested packages:"
#  [7] "  gsl-ref-psdoc | gsl-doc-pdf | gsl-doc-info | gsl-ref-html"
#  [8] "The following NEW packages will be installed:"
#  [9] "  libgsl-dev libgsl23 libgslcblas0"
# [10] "0 upgraded, 3 newly installed, 0 to remove and 34 not upgraded."
# [11] "Need to get 1,998 kB of archives."
# [12] "After this operation, 9,931 kB of additional disk space will be used."
# [13] "Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgslcblas0 amd64 2.5+dfsg-6build1 [84.6 kB]"
# [14] "Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgsl23 amd64 2.5+dfsg-6build1 [850 kB]"
# [15] "Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgsl-dev amd64 2.5+dfsg-6build1 [1,064 kB]"
# [16] "Fetched 1,998 kB in 3s (755 kB/s)"
# [17] "Selecting previously unselected package libgslcblas0:amd64.\r"
# [18] "(Reading database ... \r(Reading database ... 5%\r(Reading database ... 10%\r(Reading database ... 15%\r(Reading database ... 20%\r(Reading database ... 25%\r(Reading database ... 30%\r(Reading database ... 35%\r(Reading database ... 40%\r(Reading database ... 45%\r(Reading database ... 50%\r(Reading database ... 55%\r(Reading database ... 60%\r(Reading database ... 65%\r(Reading database ... 70%\r(Reading database ... 75%\r(Reading database ... 80%\r(Reading database ... 85%\r(Reading database ... 90%\r(Reading database ... 95%\r(Reading database ... 100%\r(Reading database ... 122545 files and directories currently installed.)\r"
# [19] "Preparing to unpack .../libgslcblas0_2.5+dfsg-6build1_amd64.deb ...\r"
# [20] "Unpacking libgslcblas0:amd64 (2.5+dfsg-6build1) ...\r"
# [21] "Selecting previously unselected package libgsl23:amd64.\r"
# [22] "Preparing to unpack .../libgsl23_2.5+dfsg-6build1_amd64.deb ...\r"
# [23] "Unpacking libgsl23:amd64 (2.5+dfsg-6build1) ...\r"
# [24] "Selecting previously unselected package libgsl-dev.\r"
# [25] "Preparing to unpack .../libgsl-dev_2.5+dfsg-6build1_amd64.deb ...\r"
# [26] "Unpacking libgsl-dev (2.5+dfsg-6build1) ...\r"
# [27] "Setting up libgslcblas0:amd64 (2.5+dfsg-6build1) ...\r"
# [28] "Setting up libgsl23:amd64 (2.5+dfsg-6build1) ...\r"
# [29] "Setting up libgsl-dev (2.5+dfsg-6build1) ...\r"
# [30] "Processing triggers for man-db (2.9.1-1) ...\r"
# [31] "Processing triggers for libc-bin (2.31-0ubuntu9.9) ...\r"

# %%
install.packages("RcppGSL")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(RcppGSL)
LdFlags()
# Out:
# -L/usr/lib/x86_64-linux-gnu -lgsl -lgslcblas -lm

# %%
system("unzip mixsqp.zip",intern = TRUE)
# Out:
#   [1] "Archive:  mixsqp.zip"
#   [2] "   creating: mixsqp/"
#   [3] "  inflating: __MACOSX/._mixsqp       "
#   [4] "   creating: mixsqp/man/"
#   [5] "  inflating: __MACOSX/mixsqp/._man   "
#   [6] "  inflating: mixsqp/.Rbuildignore    "
#   [7] "  inflating: __MACOSX/mixsqp/._.Rbuildignore  "
#   [8] "   creating: mixsqp/vignettes/"
#   [9] "  inflating: __MACOSX/mixsqp/._vignettes  "
#  [10] "  inflating: mixsqp/_pkgdown.yml     "
#  [11] "  inflating: __MACOSX/mixsqp/.__pkgdown.yml  "
#  [12] "  inflating: mixsqp/LICENSE          "
#  [13] "  inflating: __MACOSX/mixsqp/._LICENSE  "
#  [14] "   creating: mixsqp/tests/"
#  [15] "  inflating: __MACOSX/mixsqp/._tests  "
#  [16] "   creating: mixsqp/R/"
#  [17] "  inflating: __MACOSX/mixsqp/._R     "
#  [18] "  inflating: mixsqp/NAMESPACE        "
#  [19] "  inflating: __MACOSX/mixsqp/._NAMESPACE  "
#  [20] "   creating: mixsqp/docs/"
#  [21] "  inflating: __MACOSX/mixsqp/._docs  "
#  [22] "  inflating: mixsqp/README.md        "
#  [23] "  inflating: __MACOSX/mixsqp/._README.md  "
#  [24] "  inflating: mixsqp/appveyor.yml     "
#  [25] "  inflating: __MACOSX/mixsqp/._appveyor.yml  "
#  [26] "  inflating: mixsqp/DESCRIPTION      "
#  [27] "  inflating: __MACOSX/mixsqp/._DESCRIPTION  "
#  [28] "  inflating: mixsqp/.gitignore       "
#  [29] "  inflating: __MACOSX/mixsqp/._.gitignore  "
#  [30] "  inflating: mixsqp/mixsqp.Rproj     "
#  [31] "  inflating: __MACOSX/mixsqp/._mixsqp.Rproj  "
#  [32] "   creating: mixsqp/inst/"
#  [33] "  inflating: __MACOSX/mixsqp/._inst  "
#  [34] "   creating: mixsqp/data/"
#  [35] "  inflating: __MACOSX/mixsqp/._data  "
#  [36] "  inflating: mixsqp/pre-commit       "
#  [37] "  inflating: __MACOSX/mixsqp/._pre-commit  "
#  [38] "  inflating: mixsqp/.travis.yml      "
#  [39] "  inflating: __MACOSX/mixsqp/._.travis.yml  "
#  [40] "   creating: mixsqp/src/"
#  [41] "  inflating: __MACOSX/mixsqp/._src   "
#  [42] "  inflating: mixsqp/man/mixsqp.Rd    "
#  [43] "  inflating: __MACOSX/mixsqp/man/._mixsqp.Rd  "
#  [44] "  inflating: mixsqp/man/mixobjective.Rd  "
#  [45] "  inflating: __MACOSX/mixsqp/man/._mixobjective.Rd  "
#  [46] "  inflating: mixsqp/man/mixsqp-package.Rd  "
#  [47] "  inflating: __MACOSX/mixsqp/man/._mixsqp-package.Rd  "
#  [48] "  inflating: mixsqp/man/tacks.Rd     "
#  [49] "  inflating: __MACOSX/mixsqp/man/._tacks.Rd  "
#  [50] "  inflating: mixsqp/man/mixkwdual.Rd  "
#  [51] "  inflating: __MACOSX/mixsqp/man/._mixkwdual.Rd  "
#  [52] "  inflating: mixsqp/man/simulatemixdata.Rd  "
#  [53] "  inflating: __MACOSX/mixsqp/man/._simulatemixdata.Rd  "
#  [54] "  inflating: mixsqp/vignettes/mixsqp-intro.Rmd  "
#  [55] "  inflating: __MACOSX/mixsqp/vignettes/._mixsqp-intro.Rmd  "
#  [56] "   creating: mixsqp/tests/testthat/"
#  [57] "  inflating: __MACOSX/mixsqp/tests/._testthat  "
#  [58] "  inflating: mixsqp/tests/testthat.R  "
#  [59] "  inflating: __MACOSX/mixsqp/tests/._testthat.R  "
#  [60] "  inflating: mixsqp/R/mixsqp.R       "
#  [61] "  inflating: __MACOSX/mixsqp/R/._mixsqp.R  "
#  [62] "  inflating: mixsqp/R/RcppExports.R  "
#  [63] "  inflating: __MACOSX/mixsqp/R/._RcppExports.R  "
#  [64] "  inflating: mixsqp/R/misc.R         "
#  [65] "  inflating: __MACOSX/mixsqp/R/._misc.R  "
#  [66] "  inflating: mixsqp/R/tacks.R        "
#  [67] "  inflating: __MACOSX/mixsqp/R/._tacks.R  "
#  [68] "  inflating: mixsqp/R/mixsqp-package.R  "
#  [69] "  inflating: __MACOSX/mixsqp/R/._mixsqp-package.R  "
#  [70] "  inflating: mixsqp/R/objective.R    "
#  [71] "  inflating: __MACOSX/mixsqp/R/._objective.R  "
#  [72] "  inflating: mixsqp/R/rebayes.R      "
#  [73] "  inflating: __MACOSX/mixsqp/R/._rebayes.R  "
#  [74] "  inflating: mixsqp/R/zzz.R          "
#  [75] "  inflating: __MACOSX/mixsqp/R/._zzz.R  "
#  [76] "  inflating: mixsqp/R/tsvd.R         "
#  [77] "  inflating: __MACOSX/mixsqp/R/._tsvd.R  "
#  [78] "  inflating: mixsqp/R/datasim.R      "
#  [79] "  inflating: __MACOSX/mixsqp/R/._datasim.R  "
#  [80] "  inflating: mixsqp/docs/pkgdown.yml  "
#  [81] "  inflating: __MACOSX/mixsqp/docs/._pkgdown.yml  "
#  [82] "  inflating: mixsqp/docs/index.html  "
#  [83] "  inflating: __MACOSX/mixsqp/docs/._index.html  "
#  [84] "  inflating: mixsqp/docs/LICENSE.html  "
#  [85] "  inflating: __MACOSX/mixsqp/docs/._LICENSE.html  "
#  [86] "  inflating: mixsqp/docs/pkgdown.js  "
#  [87] "  inflating: __MACOSX/mixsqp/docs/._pkgdown.js  "
#  [88] "  inflating: mixsqp/docs/link.svg    "
#  [89] "  inflating: __MACOSX/mixsqp/docs/._link.svg  "
#  [90] "   creating: mixsqp/docs/articles/"
#  [91] "  inflating: __MACOSX/mixsqp/docs/._articles  "
#  [92] "  inflating: mixsqp/docs/404.html    "
#  [93] "  inflating: __MACOSX/mixsqp/docs/._404.html  "
#  [94] "  inflating: mixsqp/docs/jquery.sticky-kit.min.js  "
#  [95] "  inflating: __MACOSX/mixsqp/docs/._jquery.sticky-kit.min.js  "
#  [96] "  inflating: mixsqp/docs/LICENSE-text.html  "
#  [97] "  inflating: __MACOSX/mixsqp/docs/._LICENSE-text.html  "
#  [98] "  inflating: mixsqp/docs/pkgdown.css  "
#  [99] "  inflating: __MACOSX/mixsqp/docs/._pkgdown.css  "
# [100] "  inflating: mixsqp/docs/authors.html  "
# [101] "  inflating: __MACOSX/mixsqp/docs/._authors.html  "
# [102] "  inflating: mixsqp/docs/docsearch.js  "
# [103] "  inflating: __MACOSX/mixsqp/docs/._docsearch.js  "
# [104] "  inflating: mixsqp/docs/docsearch.css  "
# [105] "  inflating: __MACOSX/mixsqp/docs/._docsearch.css  "
# [106] "   creating: mixsqp/docs/reference/"
# [107] "  inflating: __MACOSX/mixsqp/docs/._reference  "
# [108] "  inflating: mixsqp/inst/CITATION    "
# [109] "  inflating: __MACOSX/mixsqp/inst/._CITATION  "
# [110] "   creating: mixsqp/inst/code/"
# [111] "  inflating: __MACOSX/mixsqp/inst/._code  "
# [112] "  inflating: mixsqp/data/tacks.RData  "
# [113] "  inflating: __MACOSX/mixsqp/data/._tacks.RData  "
# [114] "  inflating: mixsqp/src/objective.cpp  "
# [115] "  inflating: __MACOSX/mixsqp/src/._objective.cpp  "
# [116] "  inflating: mixsqp/src/Makevars.win  "
# [117] "  inflating: __MACOSX/mixsqp/src/._Makevars.win  "
# [118] "  inflating: mixsqp/src/mixsqp.cpp   "
# [119] "  inflating: __MACOSX/mixsqp/src/._mixsqp.cpp  "
# [120] "  inflating: mixsqp/src/misc.cpp     "
# [121] "  inflating: __MACOSX/mixsqp/src/._misc.cpp  "
# [122] "  inflating: mixsqp/src/misc.h       "
# [123] "  inflating: __MACOSX/mixsqp/src/._misc.h  "
# [124] "  inflating: mixsqp/src/objective.h  "
# [125] "  inflating: __MACOSX/mixsqp/src/._objective.h  "
# [126] "  inflating: mixsqp/src/Makevars     "
# [127] "  inflating: __MACOSX/mixsqp/src/._Makevars  "
# [128] "  inflating: mixsqp/src/mixem.cpp    "
# [129] "  inflating: __MACOSX/mixsqp/src/._mixem.cpp  "
# [130] "  inflating: mixsqp/src/RcppExports.cpp  "
# [131] "  inflating: __MACOSX/mixsqp/src/._RcppExports.cpp  "
# [132] "  inflating: mixsqp/src/mixem.h      "
# [133] "  inflating: __MACOSX/mixsqp/src/._mixem.h  "
# [134] "  inflating: mixsqp/tests/testthat/smashr.example.RData  "
# [135] "  inflating: __MACOSX/mixsqp/tests/testthat/._smashr.example.RData  "
# [136] "  inflating: mixsqp/tests/testthat/npmle.RData  "
# [137] "  inflating: __MACOSX/mixsqp/tests/testthat/._npmle.RData  "
# [138] "  inflating: mixsqp/tests/testthat/ashr.example.RData  "
# [139] "  inflating: __MACOSX/mixsqp/tests/testthat/._ashr.example.RData  "
# [140] "  inflating: mixsqp/tests/testthat/mashr.example.RData  "
# [141] "  inflating: __MACOSX/mixsqp/tests/testthat/._mashr.example.RData  "
# [142] "  inflating: mixsqp/tests/testthat/ashr.binom.example.RData  "
# [143] "  inflating: __MACOSX/mixsqp/tests/testthat/._ashr.binom.example.RData  "
# [144] "  inflating: mixsqp/tests/testthat/test_mixsqp.R  "
# [145] "  inflating: __MACOSX/mixsqp/tests/testthat/._test_mixsqp.R  "
# [146] "  inflating: mixsqp/tests/testthat/flashr.example.RData  "
# [147] "  inflating: __MACOSX/mixsqp/tests/testthat/._flashr.example.RData  "
# [148] "  inflating: mixsqp/tests/testthat/test_simulatemixdata.R  "
# [149] "  inflating: __MACOSX/mixsqp/tests/testthat/._test_simulatemixdata.R  "
# [150] "  inflating: mixsqp/docs/articles/index.html  "
# [151] "  inflating: __MACOSX/mixsqp/docs/articles/._index.html  "
# [152] "  inflating: mixsqp/docs/articles/footer.html  "
# [153] "  inflating: __MACOSX/mixsqp/docs/articles/._footer.html  "
# [154] "  inflating: mixsqp/docs/articles/mixsqp-intro.html  "
# [155] "  inflating: __MACOSX/mixsqp/docs/articles/._mixsqp-intro.html  "
# [156] "  inflating: mixsqp/docs/articles/header.html  "
# [157] "  inflating: __MACOSX/mixsqp/docs/articles/._header.html  "
# [158] "   creating: mixsqp/docs/articles/mixsqp-intro_files/"
# [159] "  inflating: __MACOSX/mixsqp/docs/articles/._mixsqp-intro_files  "
# [160] "  inflating: mixsqp/docs/reference/index.html  "
# [161] "  inflating: __MACOSX/mixsqp/docs/reference/._index.html  "
# [162] "  inflating: mixsqp/docs/reference/mixsqp.html  "
# [163] "  inflating: __MACOSX/mixsqp/docs/reference/._mixsqp.html  "
# [164] "  inflating: mixsqp/docs/reference/tacks.html  "
# [165] "  inflating: __MACOSX/mixsqp/docs/reference/._tacks.html  "
# [166] "  inflating: mixsqp/docs/reference/mixsqp-package.html  "
# [167] "  inflating: __MACOSX/mixsqp/docs/reference/._mixsqp-package.html  "
# [168] "  inflating: mixsqp/docs/reference/simulatemixdata.html  "
# [169] "  inflating: __MACOSX/mixsqp/docs/reference/._simulatemixdata.html  "
# [170] "  inflating: mixsqp/docs/reference/mixkwdual.html  "
# [171] "  inflating: __MACOSX/mixsqp/docs/reference/._mixkwdual.html  "
# [172] "  inflating: mixsqp/docs/reference/tacks-1.png  "
# [173] "  inflating: __MACOSX/mixsqp/docs/reference/._tacks-1.png  "
# [174] "  inflating: mixsqp/docs/reference/mixobjective.html  "
# [175] "  inflating: __MACOSX/mixsqp/docs/reference/._mixobjective.html  "
# [176] "  inflating: mixsqp/inst/code/test.rmosek.R  "
# [177] "  inflating: __MACOSX/mixsqp/inst/code/._test.rmosek.R  "
# [178] "   creating: mixsqp/docs/articles/mixsqp-intro_files/elevate-section-attrs-2.0/"
# [179] "  inflating: __MACOSX/mixsqp/docs/articles/mixsqp-intro_files/._elevate-section-attrs-2.0  "
# [180] "   creating: mixsqp/docs/articles/mixsqp-intro_files/figure-html/"
# [181] "  inflating: __MACOSX/mixsqp/docs/articles/mixsqp-intro_files/._figure-html  "
# [182] "   creating: mixsqp/docs/articles/mixsqp-intro_files/jquery-1.11.3/"
# [183] "  inflating: __MACOSX/mixsqp/docs/articles/mixsqp-intro_files/._jquery-1.11.3  "
# [184] "  inflating: mixsqp/docs/articles/mixsqp-intro_files/elevate-section-attrs-2.0/elevate-section-attrs.js  "
# [185] "  inflating: __MACOSX/mixsqp/docs/articles/mixsqp-intro_files/elevate-section-attrs-2.0/._elevate-section-attrs.js  "
# [186] "  inflating: mixsqp/docs/articles/mixsqp-intro_files/figure-html/plot-sqp-progress-1.png  "
# [187] "  inflating: __MACOSX/mixsqp/docs/articles/mixsqp-intro_files/figure-html/._plot-sqp-progress-1.png  "
# [188] "  inflating: mixsqp/docs/articles/mixsqp-intro_files/jquery-1.11.3/jquery.min.js  "
# [189] "  inflating: __MACOSX/mixsqp/docs/articles/mixsqp-intro_files/jquery-1.11.3/._jquery.min.js  "

# %%
system("R CMD build mixsqp",intern = TRUE)
# Out:
#  [1] "* checking for file ‘mixsqp/DESCRIPTION’ ... OK"
#  [2] "* preparing ‘mixsqp’:"
#  [3] "* checking DESCRIPTION meta-information ... OK"
#  [4] "* cleaning src"
#  [5] "* installing the package to build vignettes"
#  [6] "* creating vignettes ... OK"
#  [7] "* cleaning src"
#  [8] "* checking for LF line-endings in source and make files and shell scripts"
#  [9] "* checking for empty or unneeded directories"
# [10] "* building ‘mixsqp_0.3-48.tar.gz’"

# %%
system("R CMD INSTALL mixsqp_0.3-48.tar.gz",intern = TRUE)
# Out:
# [1] "g++ -std=gnu++11 -I\"/usr/share/R/include\" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/usr/local/lib/R/site-library/RcppArmadillo/include'    -fopenmp -DARMA_DONT_PRINT_ERRORS -DARMA_NO_DEBUG -DARMA_USE_BLAS -DARMA_DONT_USE_OPENMP -DARMA_WARN_LEVEL=1 -fpic  -g -O2 -fdebug-prefix-map=/build/r-base-dIDxrQ/r-base-4.3.0=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c RcppExports.cpp -o RcppExports.o"
# [2] "g++ -std=gnu++11 -I\"/usr/share/R/include\" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/usr/local/lib/R/site-library/RcppArmadillo/include'    -fopenmp -DARMA_DONT_PRINT_ERRORS -DARMA_NO_DEBUG -DARMA_USE_BLAS -DARMA_DONT_USE_OPENMP -DARMA_WARN_LEVEL=1 -fpic  -g -O2 -fdebug-prefix-map=/build/r-base-dIDxrQ/r-base-4.3.0=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c misc.cpp -o misc.o"
# [3] "g++ -std=gnu++11 -I\"/usr/share/R/include\" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/usr/local/lib/R/site-library/RcppArmadillo/include'    -fopenmp -DARMA_DONT_PRINT_ERRORS -DARMA_NO_DEBUG -DARMA_USE_BLAS -DARMA_DONT_USE_OPENMP -DARMA_WARN_LEVEL=1 -fpic  -g -O2 -fdebug-prefix-map=/build/r-base-dIDxrQ/r-base-4.3.0=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c mixem.cpp -o mixem.o"
# [4] "g++ -std=gnu++11 -I\"/usr/share/R/include\" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/usr/local/lib/R/site-library/RcppArmadillo/include'    -fopenmp -DARMA_DONT_PRINT_ERRORS -DARMA_NO_DEBUG -DARMA_USE_BLAS -DARMA_DONT_USE_OPENMP -DARMA_WARN_LEVEL=1 -fpic  -g -O2 -fdebug-prefix-map=/build/r-base-dIDxrQ/r-base-4.3.0=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c mixsqp.cpp -o mixsqp.o"
# [5] "g++ -std=gnu++11 -I\"/usr/share/R/include\" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/usr/local/lib/R/site-library/RcppArmadillo/include'    -fopenmp -DARMA_DONT_PRINT_ERRORS -DARMA_NO_DEBUG -DARMA_USE_BLAS -DARMA_DONT_USE_OPENMP -DARMA_WARN_LEVEL=1 -fpic  -g -O2 -fdebug-prefix-map=/build/r-base-dIDxrQ/r-base-4.3.0=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c objective.cpp -o objective.o"
# [6] "g++ -std=gnu++11 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o mixsqp.so RcppExports.o misc.o mixem.o mixsqp.o objective.o -fopenmp -llapack -lblas -lgfortran -lm -lquadmath -L/usr/lib/R/lib -lR"

# %%
system("g++ --version",intern = TRUE)
# Out:
# [1] "g++ (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0"
# [2] "Copyright (C) 2019 Free Software Foundation, Inc."
# [3] "This is free software; see the source for copying conditions.  There is NO"
# [4] "warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE."
# [5] ""

# %%
remotes::install_github("stephenslab/mixsqp",upgrade = "never",
                        verbose = TRUE,force = TRUE)
# Out:
# Downloading GitHub repo stephenslab/mixsqp@HEAD
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/RtmpsMDPtf/remotes5a23da1e037/stephenslab-mixsqp-0da946b/DESCRIPTION’ ... OK
# * preparing ‘mixsqp’:
# * checking DESCRIPTION meta-information ... OK
# * cleaning src
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building ‘mixsqp_0.3-48.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# system (cmd0): /usr/lib/R/bin/R CMD INSTALL
#
# 1): succeeded '/usr/lib/R/bin/R CMD INSTALL -l '/usr/local/lib/R/site-library' '/tmp/RtmpsMDPtf/file5a22957c947/mixsqp_0.3-48.tar.gz''

# %%
library(mixsqp)

# %%
x <- seq(0, 2*pi, length.out=50)
plot(x, sin(x))

# %%
stanmodelcode <- "
data {
    int<lower=0> N; 
    real y[N];
}

parameters {
    real mu; 

}

model {
    target += normal_lpdf(mu | 0, 10);
    target += normal_lpdf(y | mu, 1);
}"

y <- rnorm(20)
dat <- list(N = 20, y = y);

fit <- stan(model_code = stanmodelcode, model_name = "example",
            data = dat, iter = 2012, chains = 8, sample_file = 'norm.csv',
            verbose = FALSE,
            refresh = -1)

print(fit)

# %%
plot(fit)

# %%
y <- as.matrix(read.table('https://raw.github.com/wiki/stan-dev/rstan/rats.txt', header = TRUE))
x <- c(8, 15, 22, 29, 36)
xbar <- mean(x)
N <- nrow(y)
T <- ncol(y)
rats_fit <- stan(file = 'https://raw.githubusercontent.com/stan-dev/example-models/master/bugs_examples/vol1/rats/rats.stan')

# %%
rats_fit

# %%
plot(rats_fit)

# %%
## load APA data set, full version
data(APAFULL)
## Emond and Mason Branch-and-Bound algorithm.
## If the number of object is higher than 20, EMCons function may work for several minutes.
## Use either QuickCons, DECOR, FASTcons or FASTDECOR instead
CR=EMCons(APAFULL)

# %%
TR=tabulaterows(APAFULL)
CR2=FASTcons(TR$X,TR$Wk,maxiter=5)
CR3=QuickCons(TR$X,TR$Wk)
CR4=DECOR(TR$X,TR$Wk)
#####################################
### load sports data set
#data(sports)
### FAST algorithm
#CR=FASTcons(sports,maxiter=10)
#####################################
#######################################
### load Emond and Mason data set
#data(EMD)
### matrix X contains rankings
#X=EMD[,1:15]
### vector Wk contains frequencies
#Wk=EMD[,16]
### QUICK algorithm
#CR=QuickCons(X,Wk)
#######################################

# %%
data(BU)
polyplot(BU[,1:3],Wk=BU[,4])
